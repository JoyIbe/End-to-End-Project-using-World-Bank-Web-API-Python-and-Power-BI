# %%
# !pip install wbdata

# %%
# !pip show wbdata
# Out:
# Name: wbdata
# Version: 1.0.0
# Summary: A library to access World Bank data
# Home-page: https://github.com/OliverSherouse/wbdata
# Author: Oliver Sherouse
# Author-email: oliver@oliversherouse.com
# License: GPL-2.0+
# Location: C:\Users\facom\anaconda3\Lib\site-packages
# Requires: appdirs, backoff, cachetools, dateparser, decorator, requests, shelved-cache, tabulate
# Required-by:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import wbdata
print(dir(wbdata))
# Out:
# ['Client', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'cache', 'client', 'dates', 'fetcher', 'get_countries', 'get_data', 'get_dataframe', 'get_default_client', 'get_incomelevels', 'get_indicators', 'get_lendingtypes', 'get_series', 'get_sources', 'get_topics']

# %%
indicators = wbdata.get_indicators()

keyword = "GDP"
filtered = [ind for ind in indicators if keyword.lower() in ind['name'].lower()]

for ind in filtered:
    print(f"{ind['id']}: {ind['name']}")
# Out:
# 6.0.GDP_current: GDP (current $)
# 6.0.GDP_growth: GDP growth (annual %)
# 6.0.GDP_usd: GDP (constant 2005 $)
# 6.0.GDPpc_constant: GDP per capita, PPP (constant 2011 international $)
# BG.GSR.NFSV.GD.ZS: Trade in services (% of GDP)
# BG.KAC.FNEI.GD.PP.ZS: Gross private capital flows (% of GDP, PPP)
# BG.KAC.FNEI.GD.ZS: Gross private capital flows (% of GDP)
# BG.KLT.DINV.GD.PP.ZS: Gross foreign direct investment (% of GDP, PPP)
# BG.KLT.DINV.GD.ZS: Gross foreign direct investment (% of GDP)
# BI.WAG.TOTL.GD.ZS: Wage bill as a percentage of GDP
# BM.GSR.MRCH.ZS: Merchandise imports (BOP): percentage of GDP (%)
# BM.KLT.DINV.GD.ZS: Foreign direct investment, net outflows (% of GDP)
# BM.KLT.DINV.WD.GD.ZS: Foreign direct investment, net outflows (% of GDP)
# BN.CAB.XOKA.GD.ZS: Current account balance (% of GDP)
# BN.CAB.XOKA.GDP.ZS: Current account balance (% of GDP)
# BN.CAB.XOTR.ZS: Curr. acc. bal. before official transf. (% of GDP)
# ...

# %%
indicators = wbdata.get_indicators()

keyword = "GNI"
filtered = [ind for ind in indicators if keyword.lower() in ind['name'].lower()]

for ind in filtered:
    print(f"{ind['id']}: {ind['name']}")
# Out:
# 6.0.GNIpc: GNI per capita (2011 $)
# ad_hsng_any_dfcl_cogn_all: Persons with adequate housing (% of persons with any degree of cognitive difficulty)
# adj_al_alot_dfcl_cogn_1524: Adjusted prevalence of persons aged 15 to 24 years with cognitive disabilities i.e. at least a lot of functional difficulty (% of persons aged 15 to 24 years)
# adj_al_alot_dfcl_cogn_2534: Adjusted prevalence of persons aged 25 to 34 years with cognitive disabilities i.e. at least a lot of functional difficulty (% of persons aged 25 to 34 years)
# adj_al_alot_dfcl_cogn_3544: Adjusted prevalence of persons aged 35 to 44 years with cognitive disabilities i.e. at least a lot of functional difficulty (% of persons aged 35 to 44 years)
# adj_al_alot_dfcl_cogn_4554: Adjusted prevalence of persons aged 45 to 54 years with cognitive disabilities i.e. at least a lot of functional difficulty (% of persons aged 45 to 54 years)
# ...

# %%
indicators = wbdata.get_indicators()

keyword = "Inflation"
filtered = [ind for ind in indicators if keyword.lower() in ind['name'].lower()]

for ind in filtered:
    print(f"{ind['id']}: {ind['name']}")
# Out:
# FP.CPI.TOTL.ZG: Inflation, consumer prices (annual %)
# FP.FPI.TOTL.ZG: Inflation, food prices (annual %)
# FP.WPI.TOTL.ZG: Inflation, wholesale prices (annual %)
# NY.GDP.DEFL.87.ZG: Inflation, GDP deflator (annual %)
# NY.GDP.DEFL.KD.ZG: Inflation, GDP deflator (annual %)
# NY.GDP.DEFL.KD.ZG.AD: Inflation, GDP deflator: linked series (annual %)

# %%
indicators = wbdata.get_indicators()

keyword = "FDI"
filtered = [ind for ind in indicators if keyword.lower() in ind['name'].lower()]

for ind in filtered:
    print(f"{ind['id']}: {ind['name']}")
# Out:
# BX.KLT.DREM.CD.DT: Primary income on FDI (current US$)

# %%
indicators = wbdata.get_indicators()

keyword = "Gross Capital"
filtered = [ind for ind in indicators if keyword.lower() in ind['name'].lower()]

for ind in filtered:
    print(f"{ind['id']}: {ind['name']}")
# Out:
# 1500000: 1500000:GROSS CAPITAL FORMATION
# BX.KLT.DINV.DT.GI.ZS: Foreign direct investment, net inflows (% of gross capital formation)
# DT.ODA.ALLD.GI.ZS: Net official development assistance received (% of gross capital formation)
# DT.ODA.MULT.ZSI: Net ODA received from multilateral donors (% of gross capital formation)
# DT.ODA.NDAC.ZSI: Net ODA received from non-DAC bilateral donors (% of gross capital formation)
# DT.ODA.ODAT.GI.ZS: Net ODA received (% of gross capital formation)
# NE.GDI.TOTL.CD: Gross capital formation (current US$)
# NE.GDI.TOTL.CN: Gross capital formation (current LCU)
# NE.GDI.TOTL.KD: Gross capital formation (constant 2015 US$)
# NE.GDI.TOTL.KD.ZG: Gross capital formation (annual % growth)
# NE.GDI.TOTL.KN: Gross capital formation (constant LCU)
# NE.GDI.TOTL.ZS: Gross capital formation (% of GDP)

# %%
indicators = wbdata.get_indicators()

keyword = "Education"
filtered = [ind for ind in indicators if keyword.lower() in ind['name'].lower()]

for ind in filtered:
    print(f"{ind['id']}: {ind['name']}")
# Out:
# 3.1_LOW.SEC.NEW.TEACHERS: Lower secondary education, new teachers, national source
# 3.1_PRI.NEW.ENTRANTS: Primary education, new entrants, national source
# 3.11_LOW.SEC.CLASSROOMS: Lower secondary education, classrooms, national source
# 3.12_LOW.SEC.NEW.CLASSROOMS: Lower secondary education, new classrooms, national source
# 3.13_PRI.MATH.BOOK.PER.PUPIL: Ratio of textbooks per pupil, primary education, mathematics
# 3.14_PRI.LANGU.BOOK.PER.PUPIL: Ratio of textbooks per pupil, primary education, language
# 3.2_PRI.STUDENTS: Primary education, pupils, national source
# 3.3_PRI.TEACHERS: Primary education, teachers, national source
# 3.4_PRI.NEW.TEACHERS: Primary education, new teachers, national source
# 3.5_PRI.CLASSROOMS: Primary education, classrooms, national source
# 3.6_PRI.NEW.CLASSROOMS: Primary education, new classrooms, national source
# 3.7_LOW.SEC.NEW.ENTRANTS: Lower Secondary education, new entrants, national source
# ...

# %%
NY.GDP.MKTP.CD: GDP (current US$
NY.GDP.MKTP.KD.ZG: GDP growth (annual %)
NY.GNP.MKTP.CD: GNI (current US$)
NY.GNP.MKTP.KD.ZG: GNI growth (annual %)
FP.CPI.TOTL.ZG: Inflation, consumer prices (annual %)
BX.KLT.DREM.CD.DT: Primary income on FDI (current US$)
NE.GDI.TOTL.CD: Gross capital formation (current US$)
SL.UEM.1524.FM.NE.ZS: Ratio of female to male youth unemployment rate (%) (national estimate)
SI.POV.NAPR.ZS: Poverty Rate (in % of population)
SI.POV.NAHC: Poverty headcount ratio at national poverty lines (% of population)
IN.POV.LIT.RAT.TOTL: Literacy Rate (%)
SE.ADT.LITR.ZS: Literacy rate, adult total (% of people ages 15 and above)
SP.DYN.LE00.IN: Life expectancy at birth, total (years)
SP.POP.GROW: Population growth (annual %)
SE.XPD.TOTL.GB.ZS: Government expenditure on education, total (% of government expenditure)

# %%
indicators = {'Indicator Name': [
    'GDP',
    'GDP growth %',
    'GNI',
    'GNI growth',
    'Inflation Rate',
    'FDI',
    'GCF',
    'Unemployment Rate',
    'Poverty Rate',
    'Literacy Rate',
    'Life expectancy',
    'Population growth',
    'Government expenditure on education'
], 
    'Indicator ID':[
    'NY.GDP.MKTP.CD',
    'NY.GDP.MKTP.KD.ZG',
    'NY.GNP.MKTP.CD',
    'NY.GNP.MKTP.KD.ZG',
    'FP.CPI.TOTL.ZG',
    'BX.KLT.DINV.CD.WD',
    'NE.GDI.TOTL.CD',
    'SL.UEM.TOTL.ZS',
    'SI.POV.NAHC',
    'SE.ADT.LITR.ZS', 
    'SP.DYN.LE00.IN', 
    'SP.POP.GROW',
    'SE.XPD.TOTL.GB.ZS'
    ]            
}

indicators
# Out:
# {'Indicator Name': ['GDP',
#   'GDP growth %',
#   'GNI',
#   'GNI growth',
#   'Inflation Rate',
#   'FDI',
#   'GCF',
#   'Unemployment Rate',
#   'Poverty Rate',
#   'Literacy Rate',
#   'Life expectancy',
#   'Population growth',
#   'Government expenditure on education'],
#  'Indicator ID': ['NY.GDP.MKTP.CD',
#   'NY.GDP.MKTP.KD.ZG',
#   'NY.GNP.MKTP.CD',
#   'NY.GNP.MKTP.KD.ZG',
#   'FP.CPI.TOTL.ZG',
#   'BX.KLT.DINV.CD.WD',
#   'NE.GDI.TOTL.CD',
#   'SL.UEM.TOTL.ZS',
#   'SI.POV.NAHC',
#   'SE.ADT.LITR.ZS',
#   'SP.DYN.LE00.IN',
#   'SP.POP.GROW',
#   'SE.XPD.TOTL.GB.ZS']}

# %%
df_indicators2 = pd.DataFrame(indicators)
df_indicators2
# Out:
#                          Indicator Name       Indicator ID
# 0                                   GDP     NY.GDP.MKTP.CD
# 1                          GDP growth %  NY.GDP.MKTP.KD.ZG
# 2                                   GNI     NY.GNP.MKTP.CD
# 3                            GNI growth  NY.GNP.MKTP.KD.ZG
# 4                        Inflation Rate     FP.CPI.TOTL.ZG
# 5                                   FDI  BX.KLT.DINV.CD.WD
# 6                                   GCF     NE.GDI.TOTL.CD
# 7                     Unemployment Rate     SL.UEM.TOTL.ZS
# 8                          Poverty Rate        SI.POV.NAHC
# 9                         Literacy Rate     SE.ADT.LITR.ZS
# 10                      Life expectancy     SP.DYN.LE00.IN
# 11                    Population growth        SP.POP.GROW
# 12  Government expenditure on education  SE.XPD.TOTL.GB.ZS

# %%
data_df = pd.DataFrame()
data_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from datetime import datetime
data_date = (datetime(2018, 1, 1), datetime(2023, 12, 31))
data_date
# Out:
# (datetime.datetime(2018, 1, 1, 0, 0), datetime.datetime(2023, 12, 31, 0, 0))

# %%
wbdata.get_data("NY.GDP.MKTP.CD", country="all", date=data_date)
# Out:
# [{'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2023',
#   'value': 1176909900789.14,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2022',
#   'value': 1191638638185.25,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2021',
#   'value': 1085604883589.65,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
# ...

# %%
df2= pd.DataFrame()

for i in indicators['Indicator ID']:
    raw_tdata = wbdata.get_data(indicator=i, country="all", date=data_date)
    test_df = pd.DataFrame(raw_tdata).reset_index()  
    test_df = test_df[['country', 'countryiso3code', 'date', 'value']]  #only necessary columns
    indicator_name = df_indicators2.loc[df_indicators2['Indicator ID'] == i, 'Indicator Name'].values[0]
    test_df.columns = ['country', 'countryiso3code', 'year', indicator_name] #rename
    df_new = pd.concat([df2,test_df], axis=1)

# %%
df_new
# Out:
#                                                 country countryiso3code  year  \
# 0     {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2023
# 1     {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2022
# 2     {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2021
# 3     {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2020
# 4     {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2019
# ...                                                 ...             ...   ...
# 1591                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE  2022
# 1592                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE  2021
# 1593                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE  2020
# 1594                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE  2019
# 1595                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE  2018
#
#                GCF
# ...

# %%
print(data_df.columns)
# Out:
# RangeIndex(start=0, stop=0, step=1)

# %%
df_list = []

for i in indicators['Indicator ID']: 
    raw_data = wbdata.get_data(indicator=i, country="all", date=data_date) 
    data_df = pd.DataFrame(raw_data).reset_index() 
    data_df = data_df[['country', 'countryiso3code', 'date', 'value']]
    data_df['country'] = data_df['country'].apply(lambda x: x['value'] if isinstance(x, dict) else x) #unhash country in dict
    data_df.columns = ['country', 'countryiso3code', 'year','value'] #rename
    indicator_name = df_indicators2.loc[df_indicators2['Indicator ID'] == i, 'Indicator Name'].values[0] 
    data_df['Indicator Name'] = indicator_name #adds indicator column 
    df_list.append(data_df)
    
df3 = pd.concat(df_list, ignore_index=True) 
df3
# Out:
#                            country countryiso3code  year         value  \
# 0      Africa Eastern and Southern             AFE  2023  1.176910e+12
# 1      Africa Eastern and Southern             AFE  2022  1.191639e+12
# 2      Africa Eastern and Southern             AFE  2021  1.085605e+12
# 3      Africa Eastern and Southern             AFE  2020  9.334072e+11
# 4      Africa Eastern and Southern             AFE  2019  1.009747e+12
# ...                            ...             ...   ...           ...
# 20743                     Zimbabwe             ZWE  2022           NaN
# 20744                     Zimbabwe             ZWE  2021           NaN
# 20745                     Zimbabwe             ZWE  2020  1.566661e+01
# 20746                     Zimbabwe             ZWE  2019  1.046359e+01
# 20747                     Zimbabwe             ZWE  2018  1.915878e+01
#
#                             Indicator Name
# 0                                      GDP
# ...

# %%
df_indicators2.loc[df_indicators2['Indicator ID'] == 'NY.GDP.MKTP.CD', 'Indicator Name'].values[0]
# Out:
# 'GDP'

# %%
specific_df = df3.copy()
specific_df
# Out:
#                            country countryiso3code  year         value  \
# 0      Africa Eastern and Southern             AFE  2023  1.176910e+12
# 1      Africa Eastern and Southern             AFE  2022  1.191639e+12
# 2      Africa Eastern and Southern             AFE  2021  1.085605e+12
# 3      Africa Eastern and Southern             AFE  2020  9.334072e+11
# 4      Africa Eastern and Southern             AFE  2019  1.009747e+12
# ...                            ...             ...   ...           ...
# 20743                     Zimbabwe             ZWE  2022           NaN
# 20744                     Zimbabwe             ZWE  2021           NaN
# 20745                     Zimbabwe             ZWE  2020  1.566661e+01
# 20746                     Zimbabwe             ZWE  2019  1.046359e+01
# 20747                     Zimbabwe             ZWE  2018  1.915878e+01
#
#                             Indicator Name
# 0                                      GDP
# ...

# %%
#pivot Indicator name 

specific_pivoted = specific_df.pivot_table(
    index=['country', 'countryiso3code', 'year'],
    columns='Indicator Name',
    values='value'
).reset_index()

specific_pivoted
# Out:
# Indicator Name      country countryiso3code  year           FDI           GCF  \
# 0               Afghanistan             AFG  2018  1.194351e+08           NaN
# 1               Afghanistan             AFG  2019  2.340455e+07           NaN
# 2               Afghanistan             AFG  2020  1.297015e+07  2.294932e+09
# 3               Afghanistan             AFG  2021  2.060098e+07  1.853799e+09
# 4               Afghanistan             AFG  2022           NaN  2.421040e+09
# ...                     ...             ...   ...           ...           ...
# 1585               Zimbabwe             ZWE  2019  2.495000e+08  3.548607e+09
# 1586               Zimbabwe             ZWE  2020  1.503600e+08  3.532161e+09
# 1587               Zimbabwe             ZWE  2021  2.374804e+08  4.224201e+09
# 1588               Zimbabwe             ZWE  2022  3.367610e+08  4.790680e+09
# 1589               Zimbabwe             ZWE  2023  5.578730e+08  5.733567e+09
#
# ...

# %%
specific_pivoted.to_csv(r'C:\Users\IVANN\Python Web Scraping Outputs\World_ES.csv', index=False)
print('successfull')
# Out:
# successfull

# %%
print(specific_df['country'].unique())
# Out:
# ['Africa Eastern and Southern' 'Africa Western and Central' 'Arab World'
#  'Caribbean small states' 'Central Europe and the Baltics'
#  'Early-demographic dividend' 'East Asia & Pacific'
#  'East Asia & Pacific (excluding high income)'
#  'East Asia & Pacific (IDA & IBRD countries)' 'Euro area'
#  'Europe & Central Asia' 'Europe & Central Asia (excluding high income)'
#  'Europe & Central Asia (IDA & IBRD countries)' 'European Union'
#  'Fragile and conflict affected situations'
#  'Heavily indebted poor countries (HIPC)' 'High income' 'IBRD only'
#  'IDA & IBRD total' 'IDA blend' 'IDA only' 'IDA total'
#  'Late-demographic dividend' 'Latin America & Caribbean'
#  'Latin America & Caribbean (excluding high income)'
#  'Latin America & the Caribbean (IDA & IBRD countries)'
#  'Least developed countries: UN classification' 'Low & middle income'
#  'Low income' 'Lower middle income'
#  'Middle East, North Africa, Afghanistan & Pakistan'
# ...

# %%
#Only G20 + NG
countries = [
    "Argentina", "Australia", "Brazil", "Canada", "China", "France", "Germany",
    "India", "Indonesia", "Italy", "Japan", "Mexico", "Russia", "Saudi Arabia",
    "South Africa", "South Korea", "Turkey", "United Kingdom", "United States",
    "European Union", "Nigeria"
]

# %%
countries
# Out:
# ['Argentina',
#  'Australia',
#  'Brazil',
#  'Canada',
#  'China',
#  'France',
#  'Germany',
#  'India',
#  'Indonesia',
#  'Italy',
#  'Japan',
#  'Mexico',
#  'Russia',
#  'Saudi Arabia',
#  'South Africa',
#  'South Korea',
#  'Turkey',
#  'United Kingdom',
#  'United States',
#  'European Union',
#  'Nigeria']

# %%
final_df = specific_df[specific_df['country'].isin(countries)] #G20
final_df.head()
# Out:
#            country countryiso3code  year         value Indicator Name
# 78  European Union             EUU  2023  1.860267e+13            GDP
# 79  European Union             EUU  2022  1.699609e+13            GDP
# 80  European Union             EUU  2021  1.749852e+13            GDP
# 81  European Union             EUU  2020  1.550571e+13            GDP
# 82  European Union             EUU  2019  1.580930e+13            GDP

# %%
#pivot G20

df_pivoted = final_df.pivot_table(
    index=['country', 'countryiso3code', 'year'],
    columns='Indicator Name',
    values='value'
).reset_index()


df_pivoted
# Out:
# Indicator Name        country countryiso3code  year           FDI  \
# 0                   Argentina             ARG  2018  1.171677e+10
# 1                   Argentina             ARG  2019  6.649188e+09
# 2                   Argentina             ARG  2020  4.884128e+09
# 3                   Argentina             ARG  2021  6.658050e+09
# 4                   Argentina             ARG  2022  1.520060e+10
# ..                        ...             ...   ...           ...
# 103             United States             USA  2019  3.159840e+11
# 104             United States             USA  2020  1.370660e+11
# 105             United States             USA  2021  4.758050e+11
# 106             United States             USA  2022  4.089820e+11
# 107             United States             USA  2023  3.487840e+11
#
# Indicator Name           GCF           GDP  GDP growth %           GNI  \
# 0               8.719297e+10  5.248199e+11     -2.617396  5.060940e+11
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df_pivoted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              108 non-null    object
#  1   countryiso3code                      108 non-null    object
#  2   year                                 108 non-null    object
#  3   FDI                                  108 non-null    float64
#  4   GCF                                  102 non-null    float64
#  5   GDP                                  108 non-null    float64
#  6   GDP growth %                         108 non-null    float64
#  7   GNI                                  108 non-null    float64
#  8   GNI growth                           90 non-null     float64
#  9   Government expenditure on education  78 non-null     float64
#  10  Inflation Rate                       102 non-null    float64
# ...

# %%
df_pivoted['year'] = pd.to_datetime(df_pivoted['year']).dt.year

df_pivoted['year']
# Out:
# 0      2018
# 1      2019
# 2      2020
# 3      2021
# 4      2022
#        ...
# 103    2019
# 104    2020
# 105    2021
# 106    2022
# 107    2023
# Name: year, Length: 108, dtype: int32

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# Descriptive Stat

df_pivoted.describe().T
# Out:
#                                      count          mean           std  \
# Indicator Name
# year                                 108.0  2.020500e+03  1.715787e+00
# FDI                                  108.0  7.551509e+10  1.226537e+11
# GCF                                  102.0  1.341600e+12  1.950164e+12
# GDP                                  108.0  4.822176e+12  6.617171e+12
# GDP growth %                         108.0  1.954337e+00  4.190838e+00
# GNI                                  108.0  4.839714e+12  6.644644e+12
# GNI growth                            90.0  1.855234e+00  5.467515e+00
# Government expenditure on education   78.0  1.181246e+01  3.682404e+00
# Inflation Rate                       102.0  4.170725e+00  3.967623e+00
# Life expectancy                      108.0  7.631843e+01  7.656896e+00
# Literacy Rate                         15.0  8.845744e+01  1.254999e+01
# Population growth                    108.0  7.229511e-01  1.058864e+00
# ...

# %%
# Create new column to change FDI,GCF,GDP,GNI value format to billion

df_pivoted['Foreign Domestic Investment(FDI)'] = df_pivoted['FDI']/(10**9)
df_pivoted['Gross Capital Formation(GCF)'] = df_pivoted['GCF']/(10**9)
df_pivoted['Gross Domestic Product(GDP)'] = df_pivoted['GDP']/(10**9)
df_pivoted['Gross National Income(GNI)'] = df_pivoted['GNI']/(10**9)

# %%
df_pivoted.columns
# Out:
# Index(['country', 'countryiso3code', 'year', 'FDI', 'GCF', 'GDP',
#        'GDP growth %', 'GNI', 'GNI growth',
#        'Government expenditure on education', 'Inflation Rate',
#        'Life expectancy', 'Literacy Rate', 'Population growth', 'Poverty Rate',
#        'Unemployment Rate', 'Foreign Domestic Investment(FDI)',
#        'Gross Capital Formation(GCF)', 'Gross Domestic Product(GDP)',
#        'Gross National Income(GNI)'],
#       dtype='object', name='Indicator Name')

# %%
df_selected = pd.DataFrame()
df_selected
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Drop FDI,GCF,GDP,GNI

df_selected = df_pivoted.loc[:, ~df_pivoted.columns.isin(["FDI", "GCF", "GDP", "GNI"])]
df_selected
# Out:
# Indicator Name        country countryiso3code  year  GDP growth %  GNI growth  \
# 0                   Argentina             ARG  2018     -2.617396   -4.008739
# 1                   Argentina             ARG  2019     -2.000861   -4.285066
# 2                   Argentina             ARG  2020     -9.900485   -8.955691
# 3                   Argentina             ARG  2021     10.441812   13.501897
# 4                   Argentina             ARG  2022      5.269880    6.186019
# ..                        ...             ...   ...           ...         ...
# 103             United States             USA  2019      2.583825    2.711715
# 104             United States             USA  2020     -2.163029   -2.420062
# 105             United States             USA  2021      6.055053    6.075447
# 106             United States             USA  2022      2.512375    2.734726
# 107             United States             USA  2023      2.887556    2.885429
#
# ...

# %%
df_selected.to_csv(r'C:\Users\IVANN\Python Web Scraping Outputs\G20.csv', index=False)
print('successfull')
# Out:
# successfull

# %%
df_selected.describe().T.round()
# Out:
#                                      count    mean     std     min     25%  \
# Indicator Name
# year                                 102.0  2020.0     2.0  2018.0  2019.0
# GDP growth %                         102.0     2.0     4.0   -10.0     0.0
# GNI growth                            90.0     2.0     5.0   -13.0    -0.0
# Government expenditure on education   72.0    12.0     3.0     7.0    10.0
# Inflation Rate                        96.0     3.0     2.0    -2.0     2.0
# Life expectancy                      102.0    78.0     5.0    62.0    75.0
# Literacy Rate                         13.0    92.0     7.0    76.0    93.0
# Population growth                    102.0     1.0     1.0    -3.0     0.0
# Poverty Rate                          26.0    21.0    14.0     0.0    10.0
# Unemployment Rate                    102.0     7.0     6.0     2.0     4.0
# Foreign Domestic Investment(FDI)     102.0    80.0   125.0  -275.0    21.0
# ...

# %%
# distribution

fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(14,10))
axs = axs.flatten()


for i, col in enumerate(df_selected):
    sns.histplot(data=df_pivoted, x=col, kde=True, ax=axs[i])
    axs[i].set_title(col)

plt.tight_layout()
plt.show()

# %%
# distribution

fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(14,10))
axs = axs.flatten()


for i, col in enumerate(df_selected):
    sns.boxplot(data=df_pivoted, x=col, ax=axs[i])
    axs[i].set_title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Detecting Outliers

# %%
def outlier(x):
    x = pd.to_numeric(x, errors="coerce")  
    x = x.dropna() 
    q1 = x.quantile(0.25)
    q3 = x.quantile(0.75)
    iqr = q3 - q1
    return (x < q1 - 1.5 * iqr) | (x > q3 + 1.5 * iqr)



outlier_score = []

for col in df_selected:
    if pd.api.types.is_numeric_dtype(df_selected[col]):
        x = df_pivoted[col]
        outliers = outlier(x)
        score = outliers.mean()*100
        outlier_score.append((col, score))


result = pd.DataFrame(outlier_score, columns=['Column', 'Outlier_Percentage'])
result = result.sort_values('Outlier_Percentage', ascending=False)

result.round()
# Out:
#                                  Column  Outlier_Percentage
# 11         Gross Capital Formation(GCF)                18.0
# 12          Gross Domestic Product(GDP)                18.0
# 13           Gross National Income(GNI)                18.0
# 10     Foreign Domestic Investment(FDI)                17.0
# 6                         Literacy Rate                15.0
# 2                            GNI growth                10.0
# 1                          GDP growth %                 7.0
# 7                     Population growth                 7.0
# 9                     Unemployment Rate                 6.0
# 5                       Life expectancy                 1.0
# 0                                  year                 0.0
# 3   Government expenditure on education                 0.0
# 4                        Inflation Rate                 0.0
# 8                          Poverty Rate                 0.0

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=result['Column'], y=result['Outlier_Percentage'], palette=sns.color_palette("tab10"))
plt.title('Outlier Percentage')
plt.xticks(rotation=90)
plt.show()

# %%
# Null Values

df_selected.isnull().sum()
# Out:
# Indicator Name
# country                                 0
# countryiso3code                         0
# year                                    0
# GDP growth %                            0
# GNI growth                             12
# Government expenditure on education    30
# Inflation Rate                          6
# Life expectancy                         0
# Literacy Rate                          89
# Population growth                       0
# Poverty Rate                           76
# Unemployment Rate                       0
# Foreign Domestic Investment(FDI)        0
# Gross Capital Formation(GCF)            0
# Gross Domestic Product(GDP)             0
# Gross National Income(GNI)              0
# dtype: int64

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              102 non-null    object
#  1   countryiso3code                      102 non-null    object
#  2   year                                 102 non-null    int32
#  3   GDP growth %                         102 non-null    float64
#  4   GNI growth                           90 non-null     float64
#  5   Government expenditure on education  72 non-null     float64
#  6   Inflation Rate                       96 non-null     float64
#  7   Life expectancy                      102 non-null    float64
#  8   Literacy Rate                        13 non-null     float64
#  9   Population growth                    102 non-null    float64
#  10  Poverty Rate                         26 non-null     float64
# ...

# %%
# Corr

corr_df = df_selected.corr(numeric_only=True)

corr_df.round()
# Out:
# Indicator Name                       year  GDP growth %  GNI growth  \
# Indicator Name
# year                                  1.0           0.0         0.0
# GDP growth %                          0.0           1.0         1.0
# GNI growth                            0.0           1.0         1.0
# Government expenditure on education  -0.0           0.0         0.0
# Inflation Rate                        1.0           0.0         0.0
# Life expectancy                      -0.0          -0.0        -0.0
# Literacy Rate                        -1.0          -1.0        -1.0
# Population growth                     0.0           0.0        -0.0
# Poverty Rate                          0.0          -0.0        -0.0
# Unemployment Rate                    -0.0          -0.0        -0.0
# Foreign Domestic Investment(FDI)     -0.0           0.0         0.0
# Gross Capital Formation(GCF)          0.0           0.0         0.0
# Gross Domestic Product(GDP)           0.0           0.0         0.0
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(corr_df, annot=True, fmt=' .1f', cmap='turbo')
plt.show()

# %%
life_expectancy = pd.pivot_table(data=df_pivoted, index='country', columns='year', values='Life expectancy', aggfunc='mean').round(1)
life_expectancy
# Out:
# year            2018  2019  2020  2021  2022  2023
# country
# Argentina       76.8  76.8  75.9  73.9  75.8  77.4
# Australia       82.7  82.9  83.2  83.3  83.2  83.1
# Brazil          75.6  75.8  74.5  73.0  74.9  75.8
# Canada          81.8  82.2  81.5  81.5  81.2  81.6
# China           77.7  77.9  78.0  78.1  78.2  78.0
# European Union  81.0  81.3  80.4  80.3  80.7  81.4
# France          82.7  82.8  82.2  82.3  82.1  82.9
# Germany         80.9  81.3  81.0  80.8  80.6  80.5
# India           70.4  70.7  70.2  67.3  71.7  72.0
# Indonesia       70.1  70.3  68.8  67.5  70.9  71.1
# Italy           83.3  83.5  82.2  82.6  82.7  83.7
# Japan           84.2  84.4  84.6  84.4  84.0  84.0
# Mexico          74.3  74.5  70.4  69.8  74.0  75.1
# Saudi Arabia    78.8  78.3  77.6  77.1  77.3  78.7
# South Africa    65.7  66.1  65.2  62.0  65.5  66.1
# United Kingdom  81.3  81.4  80.3  80.6  81.0  81.2
# United States   78.6  78.8  77.0  76.3  77.4  78.4

# %%
#df_pivoted = pd.DataFrame()
#df_pivoted
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(life_expectancy.columns)
# Out:
# Index([2018, 2019, 2020, 2021, 2022, 2023], dtype='int32', name='year')

# %%
life_expectancy['% Change'] = round((life_expectancy[2023] - life_expectancy[2018]) * 100 / life_expectancy[2018], 1)


life_expectancy.sort_values(ascending=False, by='% Change')
# Out:
# year            2018  2019  2020  2021  2022  2023  % Change
# country
# India           70.4  70.7  70.2  67.3  71.7  72.0       2.3
# Indonesia       70.1  70.3  68.8  67.5  70.9  71.1       1.4
# Mexico          74.3  74.5  70.4  69.8  74.0  75.1       1.1
# Argentina       76.8  76.8  75.9  73.9  75.8  77.4       0.8
# South Africa    65.7  66.1  65.2  62.0  65.5  66.1       0.6
# European Union  81.0  81.3  80.4  80.3  80.7  81.4       0.5
# Australia       82.7  82.9  83.2  83.3  83.2  83.1       0.5
# Italy           83.3  83.5  82.2  82.6  82.7  83.7       0.5
# China           77.7  77.9  78.0  78.1  78.2  78.0       0.4
# Brazil          75.6  75.8  74.5  73.0  74.9  75.8       0.3
# France          82.7  82.8  82.2  82.3  82.1  82.9       0.2
# Saudi Arabia    78.8  78.3  77.6  77.1  77.3  78.7      -0.1
# United Kingdom  81.3  81.4  80.3  80.6  81.0  81.2      -0.1
# Canada          81.8  82.2  81.5  81.5  81.2  81.6      -0.2
# ...

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=life_expectancy.index, y=life_expectancy['% Change'], palette='viridis')
plt.title('% Change in Life Expectancy from 2018 to 2023')
plt.xticks(rotation=90)
plt.show()

# %%
df_selected.columns
# Out:
# Index(['country', 'countryiso3code', 'year', 'GDP growth %', 'GNI growth',
#        'Government expenditure on education', 'Inflation Rate',
#        'Life expectancy', 'Literacy Rate', 'Population growth', 'Poverty Rate',
#        'Unemployment Rate', 'Foreign Domestic Investment(FDI)',
#        'Gross Capital Formation(GCF)', 'Gross Domestic Product(GDP)',
#        'Gross National Income(GNI)'],
#       dtype='object', name='Indicator Name')

# %%
FDI = pd.pivot_table(data=df_pivoted, index='country', columns='year', values='Foreign Domestic Investment(FDI)', aggfunc='mean').round(1)
FDI['% Change'] = round((FDI[2023] - FDI[2018]) * 100 / FDI[2018], 1)
FDI.sort_values(ascending=False, by='% Change')
FDI
# Out:
# year             2018   2019   2020   2021   2022   2023  % Change
# country
# Argentina        11.7    6.6    4.9    6.7   15.2   23.9     104.3
# Australia        60.7   38.7   18.0   31.5   70.4   32.5     -46.5
# Brazil           78.2   69.2   38.3   46.4   74.6   62.4     -20.2
# Canada           42.6   48.9   29.1   60.2   50.2   42.1      -1.2
# China           235.4  187.2  253.1  344.1  190.2   51.3     -78.2
# European Union  132.9  583.1  192.0  684.1  212.5 -275.4    -307.2
# France           77.5   53.5   19.4   98.0  109.6    8.8     -88.6
# Germany         162.3   75.5  176.8  127.6   87.2   77.4     -52.3
# India            42.1   50.6   64.4   44.7   49.9   28.1     -33.3
# Indonesia        18.9   25.0   19.2   21.2   24.7   21.5      13.8
# Italy            44.2   35.8  -17.1   26.3   61.9   42.0      -5.0
# Japan            25.3   40.0   62.6   35.0   48.2   20.2     -20.2
# Mexico           37.9   29.9   31.5   35.4   39.1   30.6     -19.3
# ...

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=FDI.index, y=FDI['% Change'], palette='rocket_r')
plt.title('% Change in FDI from 2018 to 2023')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Nigeria

# %%
ng_df = ['Nigeria']
ng_df

check_df = specific_df[specific_df['country'].isin(ng_df)]
check_df.head()
# Out:
#       country countryiso3code  year         value Indicator Name
# 1158  Nigeria             NGA  2023  3.638463e+11            GDP
# 1159  Nigeria             NGA  2022  4.774034e+11            GDP
# 1160  Nigeria             NGA  2021  4.408336e+11            GDP
# 1161  Nigeria             NGA  2020  4.321989e+11            GDP
# 1162  Nigeria             NGA  2019  4.745175e+11            GDP

# %%
check_df.shape
# Out:
# (78, 5)

# %%
ng_pivoted = pd.DataFrame()
ng_pivoted
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
ng_pivoted = check_df.pivot_table(
    index=['country', 'countryiso3code', 'year'],
    columns='Indicator Name',
    values='value'
).reset_index()

ng_pivoted
# Out:
# Indicator Name  country countryiso3code  year           FDI           GDP  \
# 0               Nigeria             NGA  2018  7.752474e+08  4.217393e+11
# 1               Nigeria             NGA  2019  2.305100e+09  4.745175e+11
# 2               Nigeria             NGA  2020  2.385278e+09  4.321989e+11
# 3               Nigeria             NGA  2021  3.313210e+09  4.408336e+11
# 4               Nigeria             NGA  2022 -1.867924e+08  4.774034e+11
# 5               Nigeria             NGA  2023  1.872521e+09  3.638463e+11
#
# Indicator Name  GDP growth %           GNI  \
# 0                   1.922757  4.104869e+11
# 1                   2.208429  4.653565e+11
# 2                  -1.794253  4.274319e+11
# 3                   3.647187  4.322507e+11
# 4                   3.251681  4.645308e+11
# 5                   2.860215  3.529061e+11
#
# Indicator Name  Government expenditure on education  Inflation Rate  \
# 0                                          5.944552       12.095107
# ...

# %%
ng_pivoted.to_csv("NG.csv", index=False)

print('sucessfull')
# Out:
# sucessfull

# %%
ng_pivoted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 14 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              6 non-null      object
#  1   countryiso3code                      6 non-null      object
#  2   year                                 6 non-null      object
#  3   FDI                                  6 non-null      float64
#  4   GDP                                  6 non-null      float64
#  5   GDP growth %                         6 non-null      float64
#  6   GNI                                  6 non-null      float64
#  7   Government expenditure on education  6 non-null      float64
#  8   Inflation Rate                       6 non-null      float64
#  9   Life expectancy                      6 non-null      float64
#  10  Literacy Rate                        2 non-null      float64
# ...

# %%
ng_pivoted['year'] = pd.to_datetime(ng_pivoted['year']).dt.year



ng_pivoted['year']
# Out:
# 0    2018
# 1    2019
# 2    2020
# 3    2021
# 4    2022
# 5    2023
# Name: year, dtype: int32

# %%
ng_pivoted
# Out:
# Indicator Name  country countryiso3code  year           FDI           GDP  \
# 0               Nigeria             NGA  2018  7.752474e+08  4.217393e+11
# 1               Nigeria             NGA  2019  2.305100e+09  4.745175e+11
# 2               Nigeria             NGA  2020  2.385278e+09  4.321989e+11
# 3               Nigeria             NGA  2021  3.313210e+09  4.408336e+11
# 4               Nigeria             NGA  2022 -1.867924e+08  4.774034e+11
# 5               Nigeria             NGA  2023  1.872521e+09  3.638463e+11
#
# Indicator Name  GDP growth %           GNI  \
# 0                   1.922757  4.104869e+11
# 1                   2.208429  4.653565e+11
# 2                  -1.794253  4.274319e+11
# 3                   3.647187  4.322507e+11
# 4                   3.251681  4.645308e+11
# 5                   2.860215  3.529061e+11
#
# Indicator Name  Government expenditure on education  Inflation Rate  \
# 0                                          5.944552       12.095107
# ...

# %%
ng_pivoted.describe().T
# Out:
#                                      count          mean           std  \
# Indicator Name
# year                                   6.0  2.020500e+03  1.870829e+00
# FDI                                    6.0  1.744094e+09  1.254707e+09
# GDP                                    6.0  4.350898e+11  4.156970e+10
# GDP growth %                           6.0  2.016003e+00  1.973025e+00
# GNI                                    6.0  4.254938e+11  4.160893e+10
# Government expenditure on education    6.0  5.129696e+00  6.928556e-01
# Inflation Rate                         6.0  1.619952e+01  5.055469e+00
# Life expectancy                        6.0  5.345767e+01  6.880092e-01
# Literacy Rate                          2.0  6.258578e+01  8.057695e-01
# Population growth                      6.0  2.154044e+00  8.647660e-02
# Poverty Rate                           1.0  4.010000e+01           NaN
# Unemployment Rate                      6.0  4.726667e+00  1.044149e+00
#
# ...

# %%
# distribution

fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(14,10))
axs = axs.flatten()


for i, col in enumerate(ng_pivoted):
    sns.histplot(data=ng_pivoted, x=col, kde=True, ax=axs[i])
    axs[i].set_title(col)

plt.tight_layout()
plt.show()

# %%
def outlier(x):
    x = pd.to_numeric(x, errors="coerce")  
    x = x.dropna() 
    q1 = x.quantile(0.25)
    q3 = x.quantile(0.75)
    iqr = q3 - q1
    return (x < q1 - 1.5 * iqr) | (x > q3 + 1.5 * iqr)



outlier_ngscore = []

for col in ng_pivoted:
    if pd.api.types.is_numeric_dtype(ng_pivoted[col]):
        x = ng_pivoted[col]
        outliers = outlier(x)
        ng_score = outliers.mean()*100
        outlier_ngscore.append((col,  ng_score))


result = pd.DataFrame(outlier_ngscore, columns=['Column', 'Outlier_Percentage'])
result = result.sort_values('Outlier_Percentage', ascending=False)

result.round()
# Out:
#                                  Column  Outlier_Percentage
# 3                          GDP growth %                17.0
# 9                     Population growth                17.0
# 0                                  year                 0.0
# 1                                   FDI                 0.0
# 2                                   GDP                 0.0
# 4                                   GNI                 0.0
# 5   Government expenditure on education                 0.0
# 6                        Inflation Rate                 0.0
# 7                       Life expectancy                 0.0
# 8                         Literacy Rate                 0.0
# 10                         Poverty Rate                 0.0
# 11                    Unemployment Rate                 0.0

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=result['Column'], y=result['Outlier_Percentage'])
plt.title('Outlier Percentage')
plt.xticks(rotation=90)
plt.show()

# %%
corr_ng_df = ng_pivoted.corr(numeric_only=True)

corr_ng_df.round()

#plt.figure(figsize=(8,8))
sns.heatmap(corr_ng_df, annot=True, fmt=' .1f', cmap='turbo')
plt.xticks(rotation=90)
plt.show()

# %%
ng_pivoted.columns
# Out:
# Index(['country', 'countryiso3code', 'year', 'FDI', 'GDP', 'GDP growth %',
#        'GNI', 'Government expenditure on education', 'Inflation Rate',
#        'Life expectancy', 'Literacy Rate', 'Population growth', 'Poverty Rate',
#        'Unemployment Rate'],
#       dtype='object', name='Indicator Name')

# %%
#Poverty Rate in Nigeria

PR = pd.pivot_table(data=ng_pivoted, index='country', columns='year', values='Poverty Rate', aggfunc='mean').round(1)
PR
# Out:
# year     2018
# country
# Nigeria  40.1

# %%
#Unemployment Rate in Nigeria

UR = pd.pivot_table(data=ng_pivoted, index='country', columns='year', values='Unemployment Rate', aggfunc='mean').round(1)
UR['% Change'] = round((UR[2023] - UR[2019]) * 100 / UR[2019], 1)
UR.sort_values(ascending=False, by='% Change')
UR
# Out:
# year     2018  2019  2020  2021  2022  2023  % Change
# country
# Nigeria   5.1   5.2   5.7   5.4   3.8   3.1     -40.4

# %%
#Inflation Rate in Nigeria

IR = pd.pivot_table(data=ng_pivoted, index='country', columns='year', values='Inflation Rate', aggfunc='mean').round(1)
IR['% Change'] = round((IR[2023] - IR[2018]) * 100 / IR[2018], 1)
IR.sort_values(ascending=False, by='% Change')
IR
# Out:
# year     2018  2019  2020  2021  2022  2023  % Change
# country
# Nigeria  12.1  11.4  13.2  17.0  18.8  24.7     104.1

# %%
print(IR.columns)
# Out:
# Index([2018, 2019, 2020, 2021, 2022, 2023, '% Change'], dtype='object', name='year')

# %%
ng_pivoted
# Out:
# Indicator Name  country countryiso3code  year           FDI           GDP  \
# 0               Nigeria             NGA  2018  7.752474e+08  4.217393e+11
# 1               Nigeria             NGA  2019  2.305100e+09  4.745175e+11
# 2               Nigeria             NGA  2020  2.385278e+09  4.321989e+11
# 3               Nigeria             NGA  2021  3.313210e+09  4.408336e+11
# 4               Nigeria             NGA  2022 -1.867924e+08  4.774034e+11
# 5               Nigeria             NGA  2023  1.872521e+09  3.638463e+11
#
# Indicator Name  GDP growth %           GNI  \
# 0                   1.922757  4.104869e+11
# 1                   2.208429  4.653565e+11
# 2                  -1.794253  4.274319e+11
# 3                   3.647187  4.322507e+11
# 4                   3.251681  4.645308e+11
# 5                   2.860215  3.529061e+11
#
# Indicator Name  Government expenditure on education  Inflation Rate  \
# 0                                          5.944552       12.095107
# ...

# %%
ng_pivoted[['Literacy Rate', 'Poverty Rate', 'Unemployment Rate']] = ng_pivoted[['Literacy Rate', 'Poverty Rate', 'Unemployment Rate']].fillna(0)
